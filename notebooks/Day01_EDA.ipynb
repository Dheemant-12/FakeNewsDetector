# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
fake_df = pd.read_csv("../data/Fake.csv")
true_df = pd.read_csv("../data/True.csv")

# Add labels
fake_df["label"] = 0
true_df["label"] = 1

# Combine datasets
df = pd.concat([fake_df, true_df], ignore_index=True)

print("=" * 50)
print("Dataset Shape:")
print(df.shape)

print("\nColumns:")
print(df.columns)

print("\nFirst Five Rows:")
print(df.head())

print("\nMissing Values:")
print(df.isnull().sum())

print("\nClass Distribution:")
print(df["label"].value_counts())

# Text length analysis
df["text_length"] = df["text"].apply(len)

print("\nAverage Text Length:")
print(df["text_length"].mean())

# Plot class distribution
plt.figure(figsize=(5,4))
df["label"].value_counts().plot(kind="bar")
plt.xticks([0,1], ["Fake","Real"], rotation=0)
plt.title("Class Distribution")
plt.xlabel("News Type")
plt.ylabel("Count")
plt.show()

# Plot text length histogram
plt.figure(figsize=(8,5))
plt.hist(df["text_length"], bins=50)
plt.title("Distribution of Article Lengths")
plt.xlabel("Characters")
plt.ylabel("Frequency")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3
#       4 # Load datasets
# ----> 5 fake_df = pd.read_csv("../data/Fake.csv")
#       6 true_df = pd.read_csv("../data/True.csv")
#       7
#       8 # Add labels
#
# File c:\Users\Dheeemant\OneDrive\Desktop\Main_stream Projects\FakeNewsDetector\.venv-1\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Dheeemant\OneDrive\Desktop\Main_stream Projects\FakeNewsDetector\.venv-1\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Dheeemant\OneDrive\Desktop\Main_stream Projects\FakeNewsDetector\.venv-1\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Dheeemant\OneDrive\Desktop\Main_stream Projects\FakeNewsDetector\.venv-1\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Dheeemant\OneDrive\Desktop\Main_stream Projects\FakeNewsDetector\.venv-1\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/Fake.csv'

# %%
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt

# -----------------------------
# Duplicate Analysis
# -----------------------------
print("="*50)
print("Duplicate Rows:")
print(df.duplicated().sum())

print("\nDuplicate News Articles:")
print(df.duplicated(subset=["text"]).sum())

# -----------------------------
# Subject Distribution
# -----------------------------
print("\nSubjects:")
print(df["subject"].value_counts())

plt.figure(figsize=(8,5))
df["subject"].value_counts().plot(kind="bar")
plt.title("News Categories")
plt.xlabel("Subject")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# -----------------------------
# Publication Dates
# -----------------------------
df["date"] = pd.to_datetime(df["date"], errors="coerce")

print("\nDate Range:")
print(df["date"].min())
print(df["date"].max())

# -----------------------------
# Word Clouds
# -----------------------------
fake_text = " ".join(df[df["label"] == 0]["text"].astype(str))
real_text = " ".join(df[df["label"] == 1]["text"].astype(str))

fake_cloud = WordCloud(
    width=800,
    height=400,
    background_color="white"
).generate(fake_text)

real_cloud = WordCloud(
    width=800,
    height=400,
    background_color="white"
).generate(real_text)

plt.figure(figsize=(12,5))
plt.imshow(fake_cloud)
plt.axis("off")
plt.title("Most Frequent Words in Fake News")
plt.show()

plt.figure(figsize=(12,5))
plt.imshow(real_cloud)
plt.axis("off")
plt.title("Most Frequent Words in Real News")
plt.show()

# -----------------------------
# Top 20 Most Frequent Words
# -----------------------------
words = fake_text.lower().split()

counter = Counter(words)

print("\nTop 20 Most Common Words (Fake News):")

for word, count in counter.most_common(20):
    print(word, count)
# Out:
# ==================================================
# Duplicate Rows:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2 # Duplicate Analysis
#       3 # -----------------------------
#       4 print("="*50)
#       5 print("Duplicate Rows:")
# ----> 6 print(df.duplicated().sum())
#       7
#       8 print("\nDuplicate News Articles:")
#       9 print(df.duplicated(subset=["text"]).sum())
#
# NameError: name 'df' is not defined
